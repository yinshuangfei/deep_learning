# %% [markdown]
# ### 1.缩进
#
# //无缩进<br>
# &emsp;//缩进一个汉字字符<br>
# &emsp;&emsp;//缩进两个汉字字符<br>
# //无缩进<br>
# &ensp;//缩进一个英文字符<br>
# &ensp;&ensp;//缩进两个英文字符<br>
#
# ### 2.字体样式、字号
# size: 规定文本字体大小的值。浏览器默认的字体是微软雅黑，默认的size是3.
#
# <font face="微软雅黑" size=1><b>字号1<br></b></font>
# <font face="微软雅黑" size=2><b>字号2<br></b></font>
# <font face="微软雅黑" size=3><b>字号3<br></b></font>
# <font face="微软雅黑" size=4><b>字号4<br></b></font>
# <font face="微软雅黑" size=5><b>字号5<br></b></font>
# <font face="微软雅黑" size=5><b>字号6<br></b></font>
# <font face="微软雅黑" size=5><b>字号7<br></b></font>
#
# <font face="微软雅黑" size=4 color=#FF3399>好雨知时节<br></font>
# <font face="华文琥珀" size=4 color=#00CC00>当春乃发生<br></font>
# <font face="隶属" size=4 color=#CC66FF>随风潜入夜<br></font>
# <font face="华文行楷" size=4 color=#6699FF>润物细无声<br></font>
#
# <b>需要加粗的文字</b> 这是加粗。<br>
# <font size = 5 color=#FF0099><b>这是加粗方式1，字号5，字颜色粉</b></font><br>
# <b><font size = 5 color=#FF0099>这是加粗方式2，字号5，字颜色粉</font></b><br>
#
#
# ### 3.颜色
# 常用颜色
# ```
# color=maroon
# color=grey
# color=silver
# color=lightgrey
# color=HotPink
# color=DeepPink
# color=VioletRed
# color=Purple
# color=navy
# color=Blue
# color=DeepSkyBlue
# color=LightSkyBlue
# color=aqua
# color=DarkTurquoise（#00CED1）
# color=LightSeaGreen
# color=YellowGreen
# color=LawnGreen
# color=GreenYellow
# color=Yellow
# color=Tomato
# color=red
# color=fuchsia
# color=MediumOrchid
# color=DarkViolet
# ```
